# %% [markdown]
# <a href="https://colab.research.google.com/github/bebetakumi/bebetakumi.github.io/blob/master/aozora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install aptitude
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
# ...

# %%
# !aptitude install git make curl xz-utils file -y
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 -y
# Out:
# git is already installed at the requested version (1:2.17.1-1ubuntu0.8)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.13)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.8)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.13)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a}
# 0 packages upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 275 kB of archives. After unpacking 5,297 kB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# ...

# %%
# !pip install mecab-python3==0.7
# Out:
# ...
#      |████████████████████████████████| 51kB 5.5MB/s
# ...
#   Created wheel for mecab-python3: filename=mecab_python3-0.7-cp37-cp37m-linux_x86_64.whl size=156577 sha256=2e5845234292aca151c863501853af4356ab45456729a62af8b758e8cd5d4949
#   Stored in directory: /root/.cache/pip/wheels/4c/07/3a/5f22ccc9f381f3bc01fa023202061cd1e0e9af855292f005dd
# Successfully built mecab-python3
# ...

# %%
import MeCab

# %%
m = MeCab.Tagger()
print(m.parse("すもももももももものうち"))
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ
# EOS

# %%
from collections import defaultdict
import re
import io
import urllib.request
from zipfile import ZipFile

# %%
def load_from_url(url):
  data = urllib.request.urlopen(url).read()
  zipdata = ZipFile(io.BytesIO(data))
  filename = zipdata.namelist()[0]
  text = zipdata.read(filename).decode("shift-jis")
  text = re.sub(r'[.*?]', '', text)
  text = re.sub(r'《.*?》', '', text)
  return text

# %%
URL = "http://www.aozora.gr.jp/cards/000119/files/624_ruby_5668.zip"
text = load_from_url(URL)
text.split()[0]
# Out:
# '山月記'

# %%
def show_top10(text):
  m = MeCab.Tagger()
  node = m.parseToNode(text)
  dic = defaultdict(int)
  while node:
    a = node.feature.split(",")
    key = node.surface
    if a[0] == u"名詞" and a[1] == u"一般" and key != "":
      dic[key] += 1
    node = node.next
  for k, v in sorted(dic.items(), key = lambda x: -x[1])[0:10]:
    print(k + ":" + str(v))

# %%
URL = "https://www.aozora.gr.jp/cards/000119/files/624_ruby_5668.zip"
text = load_from_url(URL)
show_top10(text)
# Out:
# 自分:24
# 水準:23
# 声:22
# 人間:20
# 虎:19
# 徴:19
# 袁:19
# 叢:15
# 詩:9
# 傍点:8

# %%
# !apt-get -y install fonts-ipafont-gothic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 1s (8,600 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 161506 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# ...

# %%
import IPython
from wordcloud import WordCloud

# %%
def get_words(text):
  w = ""
  m = MeCab.Tagger()
  node = m.parseToNode(text)
  while node:
    a = node.feature.split(",")
    if a[0] == u"名詞" and a[1] == u"一般":
      w += node.surface + " "
    node = node.next
  return w

# %%
URL = "https://www.aozora.gr.jp/cards/000119/files/624_ruby_5668.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000119/files/621_ruby_661.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000296/files/47061_ruby_28378.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000035/files/1567_ruby_4948.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000148/files/789_ruby_5639.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000879/files/92_ruby_164.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000879/files/136_ruby_979.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000879/files/60_ruby_821.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000879/files/127_ruby_150.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/001779/files/57228_ruby_58697.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000329/files/43457_ruby_23696.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000329/files/3390_ruby_6090.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/001091/files/42315_ruby_15799.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000329/files/18376_ruby_12074.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000035/files/301_ruby_5915.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000148/files/773_ruby_5968.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000148/files/752_ruby_2438.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/001124/files/59433_ruby_73154.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000081/files/1927_ruby_17835.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")

# %%
URL = "https://www.aozora.gr.jp/cards/000081/files/45630_txt_23610.zip"
text = load_from_url(URL)
words = get_words(text)
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
wc.generate(words)
wc.to_file("wc.png")
IPython.display.Image("wc.png")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-33-3e66aaa86bc2> in <module>()
#       1 URL = "https://www.aozora.gr.jp/cards/000081/files/45630_txt_23610.zip"
#       2 text = load_from_url(URL)
# ----> 3 words = get_words(text)
#       4 fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
#       5 wc = WordCloud(background_color= "white", width= 480, height= 320, font_path= fpath)
#
# <ipython-input-13-823573579537> in get_words(text)
#       6     a = node.feature.split(",")
#       7     if a[0] == u"名詞" and a[1] == u"一般":
# ----> 8       w += node.surface + " "
#       9     node = node.next
#      10   return w
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 1: invalid continuation byte

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-738a240530f8> in <module>()
# ----> 1 print(get_words.node)
#
# AttributeError: 'function' object has no attribute 'node'
